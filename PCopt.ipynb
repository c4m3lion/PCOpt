# %%
import tkinter as tk
import os;
import glob
import stat
import sys
import shutil
import tempfile

root= tk.Tk()
root.geometry('600x300');
root.configure(background='black');
root.title("Clean PC")

def debugger(txt):
    label1 = tk.Label(root, text= txt, fg='green', font=('helvetica', 12, 'bold'))
    label1.after(5000, label1.destroy)
    label1.pack()

def clean ():  
    files = glob.glob(tempfile.gettempdir() + '\*')
    os.system("taskkill /f /im explorer.exe");#kill exploreer exe it save memory
    for f in files:
        try:
            os.remove(f) #try to remove file
        except OSError as e:
            print("Error: %s : %s" % (f, e.strerror))
            print('PermissionError do change')
            os.chmod(f, stat.S_IWRITE) # Ihave no idea
            try:
                shutil.rmtree(f) #try to remove folder
            except OSError as e:
                print("Error: %s : %s" % (f, e.strerror))
    debugger('AYE PC cleaned succesfully');

#open explorer.exe
def openExplorer():
    os.system('start explorer.exe');
    debugger('Explorere restored');
      

#delete edge
def deleteEdge():
    url = "C:/Program Files (x86)/Microsoft/Edge/Application/";
    files = glob.glob(url+'*');
    for f in files:
        if(f[len(f)-1] >='0' and f[len(f)-1] <='9'):
            f+="\Installer";
            debugger("edge found on this directory: ");
            debugger(f);
            if len(os.listdir(f) ) == 0:
                debugger("edge is uninstalled already!");
            else:    
                debugger("Uninstalling!!!")
                
                os.chdir(f);
                os.system('start cmd /k setup --uninstall --force-uninstall --system-level')
            
            
            
    
tk.Button(root, text="Clean", command=clean).pack()
tk.Button(root, text="Open Explorer", command=openExplorer).pack()
tk.Button(root, text="Delete Edge", command=deleteEdge).pack()

root.mainloop()
# Out:
# Error: C:\Users\c4m3lion\AppData\Local\Temp\03d324c3-f9ea-404c-9964-d9617bdac974.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\03d324c3-f9ea-404c-9964-d9617bdac974.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\1f538525-c350-4071-91c8-c4bc171cdc60.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\1f538525-c350-4071-91c8-c4bc171cdc60.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\2556e536-2803-482e-9f96-a48dc084fd15.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\2556e536-2803-482e-9f96-a48dc084fd15.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\48505af2-5fd8-4346-a071-43d71ddc876a.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\48505af2-5fd8-4346-a071-43d71ddc876a.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\63a45c78-0fea-43dc-9f33-3a633d42f3dd.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\63a45c78-0fea-43dc-9f33-3a633d42f3dd.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\68809325-7e0c-43d1-a2f2-b2f33e3fd6e2.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\68809325-7e0c-43d1-a2f2-b2f33e3fd6e2.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\76dcb3ad-d600-4b07-9126-def431228f2c.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\76dcb3ad-d600-4b07-9126-def431228f2c.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\7ab496fd-e577-4907-b6f0-10a71b49e830.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\7ab496fd-e577-4907-b6f0-10a71b49e830.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\88174323-08c8-472d-bbb3-4f8ccbdd5036.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\88174323-08c8-472d-bbb3-4f8ccbdd5036.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\96b4958f-17bb-40e2-a59a-4c78f2f2656f.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\96b4958f-17bb-40e2-a59a-4c78f2f2656f.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\d267110d-c43e-4820-9da4-348e291bf956.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\d267110d-c43e-4820-9da4-348e291bf956.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\e030026e-ebf0-4ce9-8387-00b0a48045b9.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\e030026e-ebf0-4ce9-8387-00b0a48045b9.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\eoi22C5.tmp : Access is denied
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\f0297611-5fbb-4673-a553-a2dc972f6e92.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\f0297611-5fbb-4673-a553-a2dc972f6e92.tmp : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\hsperfdata_c4m3lion : Access is denied
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\jna--1478885901 : Access is denied
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\lghub_agent_instance_lock : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\lghub_agent_instance_lock : The directory name is invalid
# Error: C:\Users\c4m3lion\AppData\Local\Temp\scoped_dir7948_1555340491 : Access is denied
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\WinSAT : Access is denied
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\~DFBEFAFEAE39364E30.TMP : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:\Users\c4m3lion\AppData\Local\Temp\~DFBEFAFEAE39364E30.TMP : The directory name is invalid

# %%
# Out:
# gg
