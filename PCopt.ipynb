# %%
import tkinter as tk
import os;
import glob
import stat
import sys
import shutil


root= tk.Tk()
root.geometry('600x300');
root.configure(background='black');
root.title("Clean PC")

def debugger(txt):
    label1 = tk.Label(root, text= txt, fg='green', font=('helvetica', 12, 'bold'))
    label1.after(5000, label1.destroy)
    label1.pack()

def clean ():  
    files = glob.glob('C:/Users/c4m3lion/AppData/Local/Temp/*')
    os.system("taskkill /f /im explorer.exe");#kill exploreer exe it save memory
    for f in files:
        try:
            os.remove(f) #try to remove file
        except OSError as e:
            print("Error: %s : %s" % (f, e.strerror))
            print('PermissionError do change')
            os.chmod(f, stat.S_IWRITE) # Ihave no idea
            try:
                shutil.rmtree(f) #try to remove folder
            except OSError as e:
                print("Error: %s : %s" % (f, e.strerror))
    debugger('AYE PC cleaned succesfully');

#open explorer.exe
def openExplorer():
    os.system('start explorer.exe');
    debugger('Explorere restored');
      

#delete edge
def deleteEdge():
    url = "C:/Program Files (x86)/Microsoft/Edge/Application/";
    files = glob.glob(url+'*');
    for f in files:
        if(f[len(f)-1] >='0' and f[len(f)-1] <='9'):
            f+="\Installer";
            debugger("edge found on this directory: ");
            debugger(f);
            if len(os.listdir(f) ) == 0:
                debugger("bu edge is uninstalled already!");
            else:    
                debugger("Uninstalling!!!")
                
                os.chdir(f);
                os.system('start cmd /k setup --uninstall --force-uninstall --system-level')
            
            
            
    
tk.Button(root, text="Clean", command=clean).pack()
tk.Button(root, text="Open Explorer", command=openExplorer).pack()
tk.Button(root, text="Delete Edge", command=deleteEdge).pack()

root.mainloop()
# Out:
# Error: C:/Users/c4m3lion/AppData/Local/Temp\0fc6a338-18eb-4407-aad8-3c5d6d9883cc.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:/Users/c4m3lion/AppData/Local/Temp\0fc6a338-18eb-4407-aad8-3c5d6d9883cc.tmp : The directory name is invalid
# Error: C:/Users/c4m3lion/AppData/Local/Temp\1084e317-9ddd-4169-b9ed-5c1725946ecf.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:/Users/c4m3lion/AppData/Local/Temp\1084e317-9ddd-4169-b9ed-5c1725946ecf.tmp : The directory name is invalid
# Error: C:/Users/c4m3lion/AppData/Local/Temp\217a3f97-d5a5-46c1-a4d5-fda99e70577b.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:/Users/c4m3lion/AppData/Local/Temp\217a3f97-d5a5-46c1-a4d5-fda99e70577b.tmp : The directory name is invalid
# Error: C:/Users/c4m3lion/AppData/Local/Temp\41415a73-5f9e-43ca-9e55-8b013ea6fbe5.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:/Users/c4m3lion/AppData/Local/Temp\41415a73-5f9e-43ca-9e55-8b013ea6fbe5.tmp : The directory name is invalid
# Error: C:/Users/c4m3lion/AppData/Local/Temp\4530788d-db92-4066-b4fa-8c39a92989ac.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:/Users/c4m3lion/AppData/Local/Temp\4530788d-db92-4066-b4fa-8c39a92989ac.tmp : The directory name is invalid
# Error: C:/Users/c4m3lion/AppData/Local/Temp\4f2cbe78-98b8-41fb-b40c-b9a425eb128f.tmp : The process cannot access the file because it is being used by another process
# PermissionError do change
# Error: C:/Users/c4m3lion/AppData/Local/Temp\4f2cbe78-98b8-41fb-b40c-b9a425eb128f.tmp : The directory name is invalid
# Error: C:/Users/c4m3lion/AppData/Local/Temp